# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/finally.csv')

# %%
df.head()
# Out:
#    likes  hour  word_count  char_count  polarity  subjectivity  org_mentions  \
# 0      1     0          29         181    0.1750      0.325000             0
# 1   2750    10          10          73    0.0000      0.000000             0
# 2     57    19          14         104   -0.1000      0.100000             0
# 3    152    11          22         140    0.5000      0.900000             0
# 4     41    14          26         199    0.0625      0.083333             0
#
#    place_mentions  date_mentions  time_mentions  ...  has_photo  has_video  \
# 0               0              1              1  ...          1          0
# 1               0              0              0  ...          1          0
# 2               0              0              0  ...          1          0
# 3               1              1              0  ...          1          0
# 4               0              1              0  ...          1          0
#
#    has_gif  day  weekday  month  year  is_weekend  is_morning  is_evening
# 0        0   12        5     12  2020           1           0           0
# 1        0   30        5      6  2018           1           1           0
# 2        0   29        1      9  2020           0           0           1
# 3        0    1        3     10  2020           0           1           0
# 4        0   19        4     10  2018           0           0           0
#
# [5 rows x 48 columns]

# %%
import re
import ast

def fix_embedding_string(s):
    # Remove any newline characters and extra spaces
    s = s.replace('\n', ' ').strip()

    # Insert commas between float numbers using regex
    # This inserts commas between two numbers that are separated by whitespace
    s = re.sub(r'(?<=\d)\s+(?=[\-\d])', ', ', s)

    return ast.literal_eval(s)  # Convert the string to an actual Python list

# %%
df['bert_embedding'] = df['bert_embedding'].apply(fix_embedding_string)

# %%
bert_df = pd.DataFrame(df['bert_embedding'].tolist(), index=df.index)
bert_df.columns = [f'bert_{i}' for i in range(bert_df.shape[1])]

# Add the new bert columns to df
df = df.join(bert_df)

# Drop the original bert_embedding column
df = df.drop(columns=['bert_embedding'])

print(df.shape)
# Out:
# (17331, 815)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import tensorflow as tf

# Log-Cosh loss
def log_cosh_loss(y_true, y_pred):
    return tf.reduce_mean(tf.math.log(tf.cosh(y_pred - y_true)))

# Prepare data
y = np.log1p(df['likes'])              # log1p target
X = df.drop('likes', axis=1)           # features

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# Model
model = Sequential([
    Dense(512, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(1)
])

# Compile
model.compile(optimizer=Adam(learning_rate=0.001), loss=log_cosh_loss)

# Callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=3,
    verbose=1, min_lr=1e-6
)
early_stop = EarlyStopping(
    monitor='val_loss', patience=6,
    restore_best_weights=True, verbose=1
)

# Train
model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=100,
    batch_size=32,
    callbacks=[lr_scheduler, early_stop],
    verbose=1
)

# Predict
y_pred_log = model.predict(X_test).flatten()
y_pred = np.expm1(y_pred_log)
y_true = np.expm1(y_test)

# RMSE
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
print(f"Optimized Neural Net RMSE: {rmse:.2f}")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - loss: 1.6543 - val_loss: 0.8976 - learning_rate: 0.0010
# Epoch 2/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.9607 - val_loss: 0.8415 - learning_rate: 0.0010
# Epoch 3/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.8432 - val_loss: 0.7475 - learning_rate: 0.0010
# Epoch 4/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 0.7549 - val_loss: 0.7275 - learning_rate: 0.0010
# Epoch 5/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.7075 - val_loss: 0.7266 - learning_rate: 0.0010
# Epoch 6/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.6544 - val_loss: 0.6680 - learning_rate: 0.0010
# Epoch 7/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 0.6291 - val_loss: 0.6845 - learning_rate: 0.0010
# Epoch 8/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.6042 - val_loss: 0.6532 - learning_rate: 0.0010
# Epoch 9/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.5762 - val_loss: 0.6347 - learning_rate: 0.0010
# Epoch 10/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.5380 - val_loss: 0.7028 - learning_rate: 0.0010
# Epoch 11/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.5283 - val_loss: 0.6082 - learning_rate: 0.0010
# Epoch 12/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.4999 - val_loss: 0.6303 - learning_rate: 0.0010
# Epoch 13/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.4953 - val_loss: 0.6355 - learning_rate: 0.0010
# Epoch 14/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.4740 - val_loss: 0.6069 - learning_rate: 0.0010
# Epoch 15/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.4660 - val_loss: 0.6151 - learning_rate: 0.0010
# Epoch 16/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - loss: 0.4583 - val_loss: 0.6059 - learning_rate: 0.0010
# Epoch 17/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.4514 - val_loss: 0.6221 - learning_rate: 0.0010
# Epoch 18/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.4214 - val_loss: 0.6307 - learning_rate: 0.0010
# Epoch 19/100
# 387/390 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4084
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.4086 - val_loss: 0.6350 - learning_rate: 0.0010
# Epoch 20/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.3710 - val_loss: 0.5783 - learning_rate: 5.0000e-04
# Epoch 21/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.3446 - val_loss: 0.5867 - learning_rate: 5.0000e-04
# Epoch 22/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 0.3404 - val_loss: 0.5754 - learning_rate: 5.0000e-04
# Epoch 23/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.3374 - val_loss: 0.5928 - learning_rate: 5.0000e-04
# Epoch 24/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.3267 - val_loss: 0.5918 - learning_rate: 5.0000e-04
# Epoch 25/100
# 388/390 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3095
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.3096 - val_loss: 0.5820 - learning_rate: 5.0000e-04
# Epoch 26/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.3059 - val_loss: 0.5783 - learning_rate: 2.5000e-04
# Epoch 27/100
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.2838 - val_loss: 0.5825 - learning_rate: 2.5000e-04
# Epoch 28/100
# 385/390 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2874
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.2874 - val_loss: 0.5830 - learning_rate: 2.5000e-04
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 22.
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# Optimized Neural Net RMSE: 3438.95

# %%
row = df.iloc[[999]].drop('likes', axis=1)

row_scaled = scaler.transform(row)
pred_log = model.predict(row_scaled).flatten()[0]

pred_likes = np.expm1(pred_log)

print(f"Predicted likes for row 3: {pred_likes:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Predicted likes for row 3: 89.41

# %%
model.save("op.keras")
from google.colab import files
files.download("op.keras")
